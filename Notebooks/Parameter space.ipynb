# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from qutip import *
import sys
#here, configure the path to the directory for pre-defined functions.
sys.path.append('/Users/longnguyen/Documents/GitHub/Fluxonium_berkeley/')
import plotting_settings
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 300

# %%
plt.figure(figsize = [6,4])
UMD_PRX = [0.5,6]
UChi_PRX = [0.132,3.35]
Ali = [0.52,2.2]

plt.errorbar(x=[5.899],y=[0.457],fmt='h', mfc='none',mec='#FFCD23', ecolor='C0', mew=2)
plt.errorbar(x=[5.768],y=[0.684],fmt='h', mfc='none',mec='#FFCD23', ecolor='C0', mew=2)

plt.errorbar(x=[3.35],y=[0.132],fmt='s', mfc='none',mec='#800000FF', ecolor='C1', mew=2)

plt.errorbar(x=[2.257],y=[0.523],fmt='d', mfc='none',mec='#FF6701', ecolor='C2', mew=2)
plt.errorbar(x=[2.086],y=[0.537],fmt='d', mfc='none',mec='#FF6701', ecolor='C2', mew=2)

# plt.axhline(y = 0.5)
# plt.axhline(y = 1.6)

plt.xlim([0,7])
plt.ylim([0,1.6])
plt.xlabel(r'$E_J~\mathrm{(GHz)}$')
plt.ylabel(r'$E_L~\mathrm{(GHz)}$')
plt.tight_layout()

figpath = '/Users/longnguyen/Google Drive/LBL Research/Illustration/HCF paper/'
figname = 'parameter_space.pdf'
plt.savefig(figpath+figname)

# %%
plt.figure(figsize = [5.5,3])
plt.xlim([5,1e4])
plt.xscale('log')
plt.yticks([])

plt.axvline(x=136.3, color = '#FFCD23',ymax = 0.4, lw = 1.2)
plt.axvline(x=72.3, color = '#FFCD23',ymax = 0.4, lw = 1.2)

plt.axvline(x=14, color = '#800000FF',ymax = 0.4, lw = 1.2)

plt.axvline(x=1090, color = '#FF6701',ymax = 0.4, lw = 1.2)
plt.axvline(x=1330, color = '#FF6701',ymax = 0.4, lw = 1.2)

plt.axvline(x=237, color = '#003262',ymax = 0.7, lw = 2)
plt.axvline(x=1163, color = '#003262',ymax = 0.7, lw = 2)

plt.xlabel(r'$\omega_{01}/2\pi~\mathrm{(MHz)}$')
plt.tight_layout()
figpath = '/Users/longnguyen/Google Drive/LBL Research/Illustration/HCF paper/'
figname = 'freq_space.pdf'
plt.savefig(figpath+figname)
