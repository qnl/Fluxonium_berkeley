# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
from matplotlib import pyplot as plt
from qutip import*
from scipy.special import eval_hermite as hpoly
import sys
sys.path.append('/Users/longnguyen/Documents/GitHub/Fluxonium_berkeley/')
from Fluxonium_hamiltonians import Single_small_junction as fluxonium
from Fluxonium_hamiltonians import qchard_pshapes as pshapes
from Fluxonium_hamiltonians import qchard_evolgates as gates
from scipy.optimize import minimize
from scipy.optimize import curve_fit
import plotting_settings
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 300
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman']
import scipy.linalg
from Fluxonium_hamiltonians import qchard_rotope as op
sys.path.append('/Users/longnguyen/Documents/GitHub/qtrl/')
from qtrl.benchmarking import tomography
from qtrl.analysis.state_tomography import generate_tomo_pulse_list, binary_arrays_to_bins, standard_tomography, \
    fidelity, purity, project_and_normalize_density_matrix, mcweeny_purification, dm_from_pulse, pauli_matrix, \
    renormalize_expectation_values, expectation_value_rho
from itertools import product
figpath = '/Users/longnguyen/Google Drive/LBL Research/Illustration/HCF paper/'
# Out:
# /Users/longnguyen/Documents/GitHub/qtrl/qtrl/benchmarking/tomography.py:297: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if p is not 'I':
# WARNING:qtrl.PLOTTING:Unable to import TrueQ!
# /Users/longnguyen/Documents/GitHub/qtrl/qtrl/sequencer/library_tools.py:35: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   prefix is not '' or suffix is not '') else 90
# /Users/longnguyen/Documents/GitHub/qtrl/qtrl/sequencer/library_tools.py:35: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   prefix is not '' or suffix is not '') else 90
# /Users/longnguyen/Documents/GitHub/qtrl/qtrl/sequencer/library_tools.py:37: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   prefix is not '' or suffix is not '') else 180
# /Users/longnguyen/Documents/GitHub/qtrl/qtrl/sequencer/library_tools.py:37: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   prefix is not '' or suffix is not '') else 180
# ...

# %%
plt.figure(figsize = [7,4])

x_array = np.array([3,5,7,9,11])
y_array = [np.array([0.00321667]), np.array([0.00038889]), np.array([3.16666667e-05]),np.array([2.5e-06]), np.array([2.77777778e-07])]
y_error = [np.array([4.64720737e-05]), np.array([4.64720737e-05]), np.array([4.19428605e-06]),np.array([3.7267753e-07]), np.array([1.24225981e-07])]
plt.errorbar(x_array,y_array,yerr = y_error,fmt='s', mfc='none',mec='C0', ecolor='C0', mew=1.5,label=r'$300~\mathrm{\mu s}$')

y_array = np.array([0.00235,0.00029444,1.53061224e-05,1.11111111e-06, 1.11111111e-07])
y_error = np.array([6.18533932e-05,6.18533932e-05,2.9160369e-06,2.48451859e-07, 7.85674158e-08])
plt.errorbar(x_array,y_array,yerr = y_error,fmt='d', mfc='none',mec='C1', ecolor='C1', mew=1.5,label=r'$700~\mathrm{\mu s}$')

y_array = np.array([0.00229444,0.00023333,1.61111111e-05,1.22222222e-06,4.44444444e-08])
y_error = np.array([5.0911567e-05,5.0911567e-05,2.99173413e-06,2.60578494e-07,3.14269674e-08])
plt.errorbar(x_array,y_array,yerr = y_error,fmt='h', mfc='none',mec='C2', ecolor='C2', mew=1.5,label=r'$1~\mathrm{ms}$')

plt.yscale('log')
plt.ylim([5e-9,1e-1])
plt.xlim([2,12])
plt.xticks([3,5,7,9,11])
plt.grid()
plt.xlabel('Code distance $d$')
plt.ylabel(r'Logical error rate $\varepsilon_L$')

# twin_axes = axes.twinx()
# twin_axes.plot(x_nice, x_nice**2*2-1, color = 'C4')
# twin_axes.set_yscale('log')
# twin_axes.set_ylim([5,2000])
# twin_axes.set_xlim([1,29])
# twin_axes.set_ylabel('Number of qubits')

plt.legend()
plt.tight_layout()
figname = 'code_distance.pdf'
plt.savefig(figpath+figname)
# Out:
# <ipython-input-3-6abcee4b4655>:6: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.errorbar(x_array,y_array,yerr = y_error,fmt='s', mfc='none',mec='C0', ecolor='C0', mew=1.5,label=r'$300~\mathrm{\mu s}$')

# %%
d = np.array([3,5,7,9])
error=[array([0.00321667]) array([0.00038889]) array([3.16666667e-05])
 array([2.5e-06]) array([2.77777778e-07])]
std=[array([4.64720737e-05]) array([4.64720737e-05]) array([4.19428605e-06])
 array([3.7267753e-07]) array([1.24225981e-07])]
plt.errorbar(d,error,yerr = stdfmt='d', ecolor='C0', mew=1,label='Numeric')
# Out:
#   File "<ipython-input-2-f2eb194f9a02>", line 2
#     error=[array([0.00321667]) array([0.00038889]) array([3.16666667e-05])
#                                ^
# SyntaxError: invalid syntax
